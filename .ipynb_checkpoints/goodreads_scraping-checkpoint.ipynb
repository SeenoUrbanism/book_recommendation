# %%
import pandas as pd
import os
import random
import re
from bs4 import BeautifulSoup
import requests
import time

# %%
prefix = 'https://www.goodreads.com/shelf/show/'

# %%
ls = ['poetry', 'adult', 'lgbt', 'dark-romance', 'christian', 'dark',
       'enemies-to-lovers', 'feminism', 'animals', 'novella', 'war',
       'friendship', 'unfinished', 'spirituality', 'love',
       'biography-memoir', 'smut', 'second-chance', 'forced-proximity',
       'holiday', 'relationships', 'race', 'slow-burn', 'cozy',
       'graphic-novels-comics', 'roman', 'death', 'summer',
       'science-fiction-fantasy', 'agatha-christie', 'inspirational',
       'dark-academia', 'anthologies', 'space', 'harry-potter',
       'found-family', 'romantic', 'why-choose', 'summer-reads',
       'emotional', 'grief', 'medical', 'horror-thriller', 'disability',
       'mafia-romance', 'comics-manga', 'fake-dating',
       'small-town-romance', 'family-drama', 'middle-east', 'shakespeare',
       'new-york', 'united-states', 'second-chance-romance',
       'productivity', 'teaching', 'gender', 'textbooks', 'indigenous',
       'graphic-novels-manga', 'futuristic', 'hockey-romance', 'london',
       'sequential-art', 'urban', 'satire', 'college-romance',
       'native-american', 'witchcraft', 'football', 'beach-reads',
       'sexuality', 'workplace-romance', 'occult', 'social', 'amish']

# %%
urls = [f'{prefix}{genre}' for genre in ls]

# %%
urls
# Out:
# ['https://www.goodreads.com/shelf/show/poetry',
#  'https://www.goodreads.com/shelf/show/adult',
#  'https://www.goodreads.com/shelf/show/lgbt',
#  'https://www.goodreads.com/shelf/show/dark-romance',
#  'https://www.goodreads.com/shelf/show/christian',
#  'https://www.goodreads.com/shelf/show/dark',
#  'https://www.goodreads.com/shelf/show/enemies-to-lovers',
#  'https://www.goodreads.com/shelf/show/feminism',
#  'https://www.goodreads.com/shelf/show/animals',
#  'https://www.goodreads.com/shelf/show/novella',
#  'https://www.goodreads.com/shelf/show/war',
#  'https://www.goodreads.com/shelf/show/friendship',
#  'https://www.goodreads.com/shelf/show/unfinished',
#  'https://www.goodreads.com/shelf/show/spirituality',
#  'https://www.goodreads.com/shelf/show/love',
#  'https://www.goodreads.com/shelf/show/biography-memoir',
#  'https://www.goodreads.com/shelf/show/smut',
#  'https://www.goodreads.com/shelf/show/second-chance',
#  'https://www.goodreads.com/shelf/show/forced-proximity',
#  'https://www.goodreads.com/shelf/show/holiday',
#  'https://www.goodreads.com/shelf/show/relationships',
#  'https://www.goodreads.com/shelf/show/race',
#  'https://www.goodreads.com/shelf/show/slow-burn',
#  'https://www.goodreads.com/shelf/show/cozy',
#  'https://www.goodreads.com/shelf/show/graphic-novels-comics',
#  'https://www.goodreads.com/shelf/show/roman',
#  'https://www.goodreads.com/shelf/show/death',
#  'https://www.goodreads.com/shelf/show/summer',
#  'https://www.goodreads.com/shelf/show/science-fiction-fantasy',
#  'https://www.goodreads.com/shelf/show/agatha-christie',
#  'https://www.goodreads.com/shelf/show/inspirational',
#  'https://www.goodreads.com/shelf/show/dark-academia',
#  'https://www.goodreads.com/shelf/show/anthologies',
#  'https://www.goodreads.com/shelf/show/space',
#  'https://www.goodreads.com/shelf/show/harry-potter',
#  'https://www.goodreads.com/shelf/show/found-family',
#  'https://www.goodreads.com/shelf/show/romantic',
#  'https://www.goodreads.com/shelf/show/why-choose',
#  'https://www.goodreads.com/shelf/show/summer-reads',
#  'https://www.goodreads.com/shelf/show/emotional',
#  'https://www.goodreads.com/shelf/show/grief',
#  'https://www.goodreads.com/shelf/show/medical',
#  'https://www.goodreads.com/shelf/show/horror-thriller',
#  'https://www.goodreads.com/shelf/show/disability',
#  'https://www.goodreads.com/shelf/show/mafia-romance',
#  'https://www.goodreads.com/shelf/show/comics-manga',
#  'https://www.goodreads.com/shelf/show/fake-dating',
#  'https://www.goodreads.com/shelf/show/small-town-romance',
#  'https://www.goodreads.com/shelf/show/family-drama',
#  'https://www.goodreads.com/shelf/show/middle-east',
#  'https://www.goodreads.com/shelf/show/shakespeare',
#  'https://www.goodreads.com/shelf/show/new-york',
#  'https://www.goodreads.com/shelf/show/united-states',
#  'https://www.goodreads.com/shelf/show/second-chance-romance',
#  'https://www.goodreads.com/shelf/show/productivity',
#  'https://www.goodreads.com/shelf/show/teaching',
#  'https://www.goodreads.com/shelf/show/gender',
#  'https://www.goodreads.com/shelf/show/textbooks',
#  'https://www.goodreads.com/shelf/show/indigenous',
#  'https://www.goodreads.com/shelf/show/graphic-novels-manga',
#  'https://www.goodreads.com/shelf/show/futuristic',
#  'https://www.goodreads.com/shelf/show/hockey-romance',
#  'https://www.goodreads.com/shelf/show/london',
#  'https://www.goodreads.com/shelf/show/sequential-art',
#  'https://www.goodreads.com/shelf/show/urban',
#  'https://www.goodreads.com/shelf/show/satire',
#  'https://www.goodreads.com/shelf/show/college-romance',
#  'https://www.goodreads.com/shelf/show/native-american',
#  'https://www.goodreads.com/shelf/show/witchcraft',
#  'https://www.goodreads.com/shelf/show/football',
#  'https://www.goodreads.com/shelf/show/beach-reads',
#  'https://www.goodreads.com/shelf/show/sexuality',
#  'https://www.goodreads.com/shelf/show/workplace-romance',
#  'https://www.goodreads.com/shelf/show/occult',
#  'https://www.goodreads.com/shelf/show/social',
#  'https://www.goodreads.com/shelf/show/amish']

# %%
url = "https://www.goodreads.com/shelf"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)",
    "Accept-Language": "en-US,en;q=0.9",
}

r = requests.get(url, headers=headers)

# %%
r = requests.get("https://www.goodreads.com/shelf/")
print(r.status_code)
print(r.text[:2000])
# Out:
# 403
#
# <!-- This is a random-length HTML comment: ... -->

# %%
# BASE = "https://www.goodreads.com/shelf/show/"
# shelves = [
#     "to-read",
#     "currently-reading",
#     "fiction",
#     "nonfiction",
#     "fantasy",
#     "favorites",
#     "romance",
#     "owned",
#     "non-fiction",
#     "2024",
#     "2025",
#     "2023",
#     "manga",
#     "classics",
#     "2022",
#     "history",
#     "series",
#     "science-fiction",
#     "horror",
#     "comics",
#     "thriller",
#     "poetry",
#     "philosophy",
#     "biography",
#     "childrens",
#     "crime",
#     "science",
#     "adventure",
#     "psychology",
#     "magic",
#     "children",
#     "novels",
# ]

# def scrape_shelf(slug, pages=1):
#     records = []
#     for p in range(1, pages+1):
#         url = f"{BASE}{slug}?page={p}"
#         r = requests.get(url)
#         soup = BeautifulSoup(r.text, "html.parser")

#         books = soup.select("div.elementList")
#         for b in books:
#             t = b.select_one("a.bookTitle")
#             title = t.get_text(strip=True) if t else None

#             a = b.select_one("span[itemprop='name']")
#             author = a.get_text(strip=True) if a else None

#             rating_el = b.select_one("span.greyText.smallText")
#             pub_year = None
#             avg_rating = None
#             rating_count = None

#             if rating_el:
#                 txt = rating_el.get_text(" ", strip=True)
#                 parts = txt.split("—")

#                 if "avg rating" in parts[0]:
#                     avg_rating = parts[0].replace("avg rating", "").strip()

#                 if len(parts) > 1 and "ratings" in parts[1]:
#                     rating_count = parts[1].replace("ratings", "").strip()

#                 for p_ in parts:
#                     if "published" in p_:
#                         pub_year = p_.replace("published", "").strip()

#             records.append({
#                 "shelf": slug,
#                 "title": title,
#                 "author": author,
#                 "avg_rating": avg_rating,
#                 "rating_count": rating_count,
#                 "pub_year": pub_year
#             })
#         time.sleep(1)
#     return records


# all_records = []
# for s in shelves:
#     all_records += scrape_shelf(s, pages=2)

# df = pd.DataFrame(all_records).drop_duplicates().reset_index(drop=True)
# df

# %%
def extract_genre(url):
    return url.split("/shelf/show/")[-1]

# %%
def scrape_shelf_page(url):
    headers = {"User-Agent": "Mozilla/5.0"}
    r = requests.get(url, headers=headers)
    soup = BeautifulSoup(r.text, "html.parser")

    genre = url.split("/shelf/show/")[-1]

    records = []

    books = soup.select("div.elementList")
    for b in books:

        # Title
        t = b.select_one("a.bookTitle")
        title = t.get_text(strip=True) if t else None

        # Author
        a = b.select_one("span[itemprop='name']")
        author = a.get_text(strip=True) if a else None

        # Rating & year
        rating_el = b.select_one("span.greyText.smallText")
        avg_rating, rating_count, pub_year = None, None, None

        if rating_el:
            txt = rating_el.get_text(" ", strip=True)
            parts = [p.strip() for p in txt.split("—")]

            # avg rating
            if parts and "avg rating" in parts[0]:
                avg_rating = parts[0].replace("avg rating", "").strip()

            # rating count
            if len(parts) > 1 and "ratings" in parts[1]:
                rating_count = parts[1].replace("ratings", "").strip()

            # published year
            for p in parts:
                if "published" in p:
                    pub_year = p.replace("published", "").strip()

        records.append({
            "title": title,
            "author": author,
            "avg_rating": avg_rating,
            "rating_count": rating_count,
            "year_published": pub_year,
            "genre": genre               
        })

    return records

all_data = []

for url in urls:     # urls must be a list of strings
    records = scrape_shelf_page(url)
    all_data.extend(records)

df = pd.DataFrame(all_data)
df
# Out:
#                                                   title                author  \
# 0                            Milk and honey (Paperback)             Rupi Kaur
# 1                   Where the Sidewalk Ends (Hardcover)      Shel Silverstein
# 2                   The Sun and Her Flowers (Paperback)             Rupi Kaur
# 3     The Princess Saves Herself in This One (Women ...       Amanda Lovelace
# 4                           Leaves of Grass (Paperback)          Walt Whitman
# ...                                                 ...                   ...
# 3937  An Amish Christmas: A Choice to Forgive/A Mira...          Beth Wiseman
# 3938          A Simple Amish Christmas (Kindle Edition)      Vannetta Chapman
# 3939   A Sister's Secret (Sisters of Holmes County, #1)  Wanda E. Brunstetter
# 3940                                               None                  None
# 3941                                               None                  None
#
#      avg_rating rating_count year_published   genre
# 0          3.96      791,621           2014  poetry
# 1          4.35    1,495,267           1974  poetry
# 2          4.08      370,169           2018  poetry
# 3          3.82      158,105           2016  poetry
# 4          4.11      115,706           1855  poetry
# ...         ...          ...            ...     ...
# 3937       4.27        2,334           2009   amish
# 3938       3.99        3,717           2010   amish
# 3939       4.16        3,173           2007   amish
# 3940       None         None           None   amish
# 3941       None         None           None   amish
#
# [3942 rows x 6 columns]

# %%
books = df.to_csv("goodreads_books.csv", index=False)
